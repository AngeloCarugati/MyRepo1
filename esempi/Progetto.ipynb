# %%
from gensim.models import Word2Vec
import numpy as np
import pandas as pd
from transformers import BertTokenizer
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize 
import string
from nltk.corpus import stopwords

with open('/home/acarugat/Testi/Presidenti/MattarellaFine2024.txt', 'r') as matta24:
    mattarella24 = matta24.read()
with open('/home/acarugat/Testi/Presidenti/MattarellaFine2023.txt', 'r') as matta23:
    mattarella23 = matta23.read()
    
sentences = sent_tokenize(mattarella24, language='italian')
print (sentences)
# Out:
# ['Care concittadine e cari concittadini,\n\nquesto nostro incontro tradizionale mi consente di rivolgere l’augurio più sincero a tutti voi, a chi si trova in Italia e agli italiani che sono all’estero.', 'Stiamo vivendo come ogni fine anno ore di attesa per un tempo nuovo che viene e che speriamo migliore.', 'Ore in cui cerchiamo la serenità rinsaldando i nostri rapporti.', 'Nelle nostre comunità, nelle famiglie, nelle amicizie.', 'Facciamo i nostri auguri e ne riceviamo.', 'Non è soltanto un rito, è la dimostrazione della nostra natura più autentica, quella che ci chiama alla relazione con gli altri.', 'Lo facciamo, dobbiamo farlo tanto più in quanto viviamo momenti difficili.', 'Quando migliaia di vittime civili delle guerre in corso turbano tragicamente le nostre coscienze.', 'Nella notte di Natale si è diffusa la notizia che a Gaza una bambina di pochi giorni è morta assiderata.', 'Nella stessa notte di Natale feroci bombardamenti russi hanno colpito le centrali di energia delle città dell’Ucraina per costringere quella popolazione civile al buio e al gelo.', 'Gli innocenti rapiti da Hamas, e tuttora ostaggi, vivono un secondo inizio di anno in condizioni disumane.', 'Queste forme di barbarie non risparmiano neppure il Natale e le festività più sentite.', 'Eppure mai come adesso la pace grida la sua urgenza.', 'La pace che la nostra Costituzione indica come obiettivo irrinunziabile, che l’Italia ha sempre perseguito, anche con l’importante momento quest’anno della presidenza del G7.', 'La pace di cui l’Unione Europea è storica espressione.', 'La pace che non significa sottomettersi alla prepotenza di chi aggredisce gli altri Paesi con le armi, ma la pace del rispetto dei diritti umani, la pace del diritto di ogni popolo alla libertà e alla dignità.', 'Perché è giusto.', 'E - se questo motivo non fosse ritenuto sufficiente - perché è l’unica garanzia di una vera pace, evitando che vengano aggrediti altri Paesi d’Europa.', 'Questo è, quindi, il primo augurio che tutti ci rivolgiamo.', 'Che il nuovo anno porti vera pace ovunque.', 'Interpreto, in queste ore, l’angoscia di tutti per la detenzione di Cecilia Sala.', 'Le siamo vicini in attesa di rivederla al più presto in Italia.', 'Quanto avviene segnala ancora una volta il valore della libera informazione.', 'Tanti giornalisti rischiano la vita per documentare quel che accade nelle sciagurate guerre ai confini dell’Europa, in Medio Oriente e altrove.', 'Spesso pagano a caro prezzo il servizio che rendono alla comunità.', 'La notte di Natale Papa Francesco - cui invio auguri pieni di riconoscenza - ha aperto il Giubileo, facendo risuonare nel mondo il richiamo alla speranza.', 'Quelle di questa sera sono ore di speranza nel futuro, nell’anno che viene.', 'Tocca a noi saperla tradurre in realtà.', 'Cosa significa concretamente coltivare fiducia in un tempo segnato, oltre che dalle guerre, da squilibri, da conflitti?', 'Vi è bisogno di riorientare la convivenza, il modo di vivere insieme.', 'In questo periodo sembra che il mondo sia sottoposto a una allarmante forza centrifuga, capace di dividere, di allontanare, di radicalizzare le contrapposizioni.', 'Sono lacerate le pubbliche opinioni.', 'Faglie profonde attraversano le nostre società.', 'La realtà che viviamo ci presenta contraddizioni che generano smarrimento, sgomento, talvolta senso di impotenza.', 'A livello globale aumenta in modo esponenziale la ricchezza di pochissimi mentre si espande la povertà di tanti.', 'La crescita della spesa in armamenti, innescata nel mondo dall’aggressione della Russia all’Ucraina - che costringe anche noi a provvedere alla nostra difesa - ha toccato quest’anno la cifra record di 2.443 miliardi di dollari.', 'Otto volte di più di quanto stanziato alla recente Cop 29, a Baku, per contrastare il cambiamento climatico, esigenza, questa, vitale per l’umanità.', 'Una sconfortante sproporzione.', 'Luci e ombre riguardano anche la nostra Italia.', 'La scienza, la ricerca, le nuove tecnologie apron ...

# %%
import re

def preprocess_file(input_file, output_file):
    with open(input_file, 'r', encoding='utf-8') as infile, open(output_file, 'w', encoding='utf-8') as outfile:
        for line in infile:
            # Dividi la riga in frasi
            sentences = re.split(r'[.!?]', line.strip())
            for sentence in sentences:
                if sentence:  # Ignora frasi vuote
                    outfile.write(sentence.strip() + '\n')  # Scrivi ogni frase su una nuova riga

# Pre-processa il file
preprocess_file("/home/acarugat/Testi/Presidenti/MattarellaFine2024.txt", "/home/acarugat/Testi/Presidenti/MattarellaFine2024-preprocessato.txt")
print("File preprocessato!")

# Usa il file preprocessato con Word2Vec
model = Word2Vec(corpus_file="/home/acarugat/Testi/Presidenti/MattarellaFine2024-preprocessato.txt", vector_size=100, window=5, min_count=1, workers=4)
model.save("word2vec_model.model")
print("Modello addestrato e salvato!")
# Out:
# File preprocessato!
# Modello addestrato e salvato!

# %%
with open('/home/acarugat/Testi/Presidenti/MattarellaFine2024-preprocessato.txt', 'r') as matta24:
    mattarella24 = matta24.read()
    
tokens = word_tokenize (mattarella24, language='italian')
print (tokens)
# Out:
# ['Care', 'concittadine', 'e', 'cari', 'concittadini', ',', 'questo', 'nostro', 'incontro', 'tradizionale', 'mi', 'consente', 'di', 'rivolgere', 'l', '’', 'augurio', 'più', 'sincero', 'a', 'tutti', 'voi', ',', 'a', 'chi', 'si', 'trova', 'in', 'Italia', 'e', 'agli', 'italiani', 'che', 'sono', 'all', '’', 'estero', 'Stiamo', 'vivendo', 'come', 'ogni', 'fine', 'anno', 'ore', 'di', 'attesa', 'per', 'un', 'tempo', 'nuovo', 'che', 'viene', 'e', 'che', 'speriamo', 'migliore', 'Ore', 'in', 'cui', 'cerchiamo', 'la', 'serenità', 'rinsaldando', 'i', 'nostri', 'rapporti', 'Nelle', 'nostre', 'comunità', ',', 'nelle', 'famiglie', ',', 'nelle', 'amicizie', 'Facciamo', 'i', 'nostri', 'auguri', 'e', 'ne', 'riceviamo', 'Non', 'è', 'soltanto', 'un', 'rito', ',', 'è', 'la', 'dimostrazione', 'della', 'nostra', 'natura', 'più', 'autentica', ',', 'quella', 'che', 'ci', 'chiama', 'alla', 'relazione', 'con', 'gli', 'altri', 'Lo', 'facciamo', ',', 'dobbiamo', 'farlo', 'tanto', 'più', 'in', 'quanto', 'viviamo', 'momenti', 'difficili', 'Quando', 'migliaia', 'di', 'vittime', 'civili', 'delle', 'guerre', 'in', 'corso', 'turbano', 'tragicamente', 'le', 'nostre', 'coscienze', 'Nella', 'notte', 'di', 'Natale', 'si', 'è', 'diffusa', 'la', 'notizia', 'che', 'a', 'Gaza', 'una', 'bambina', 'di', 'pochi', 'giorni', 'è', 'morta', 'assiderata', 'Nella', 'stessa', 'notte', 'di', 'Natale', 'feroci', 'bombardamenti', 'russi', 'hanno', 'colpito', 'le', 'centrali', 'di', 'energia', 'delle', 'città', 'dell', '’', 'Ucraina', 'per', 'costringere', 'quella', 'popolazione', 'civile', 'al', 'buio', 'e', 'al', 'gelo', 'Gli', 'innocenti', 'rapiti', 'da', 'Hamas', ',', 'e', 'tuttora', 'ostaggi', ',', 'vivono', 'un', 'secondo', 'inizio', 'di', 'anno', 'in', 'condizioni', 'disumane', 'Queste', 'forme', 'di', 'barbarie', 'non', 'risparmiano', 'neppure', 'il', 'Natale', 'e', 'le', 'festività', 'più', 'sentite', 'Eppure', 'mai', 'come', 'adesso', 'la', 'pace', 'grida', 'la', 'sua', 'urgenza', 'La', 'pace', 'che', 'la', 'nostra', 'Costituzione', 'indica', 'come', 'obiettivo', 'irrinunziabile', ',', 'che', 'l', '’', 'Italia', 'ha', 'sempre', 'perseguito', ',', 'anche', 'con', 'l', '’', 'importante', 'momento', 'quest', '’', 'anno', 'della', 'presidenza', 'del', 'G7', 'La', 'pace', 'di', 'cui', 'l', '’', 'Unione', 'Europea', 'è', 'storica', 'espressione', 'La', 'pace', 'che', 'non', 'significa', 'sottomettersi', 'alla', 'prepotenza', 'di', 'chi', 'aggredisce', 'gli', 'altri', 'Paesi', 'con', 'le', 'armi', ',', 'ma', 'la', 'pace', 'del', 'rispetto', 'dei', 'diritti', 'umani', ',', 'la', 'pace', 'del', 'diritto', 'di', 'ogni', 'popolo', 'alla', 'libertà', 'e', 'alla', 'dignità', 'Perché', 'è', 'giusto', 'E', '-', 'se', 'questo', 'motivo', 'non', 'fosse', 'ritenuto', 'sufficiente', '-', 'perché', 'è', 'l', '’', 'unica', 'garanzia', 'di', 'una', 'vera', 'pace', ',', 'evitando', 'che', 'vengano', 'aggrediti', 'altri', 'Paesi', 'd', '’', 'Europa', 'Questo', 'è', ',', 'quindi', ',', 'il', 'primo', 'augurio', 'che', 'tutti', 'ci', 'rivolgiamo', 'Che', 'il', 'nuovo', 'anno', 'porti', 'vera', 'pace', 'ovunque', 'Interpreto', ',', 'in', 'queste', 'ore', ',', 'l', '’', 'angoscia', 'di', 'tutti', 'per', 'la', 'detenzione', 'di', 'Cecilia', 'Sala', 'Le', 'siamo', 'vicini', 'in', 'attesa', 'di', 'rivederla', 'al', 'più', 'presto', 'in', 'Italia', 'Quanto', 'avviene', 'segnala', 'ancora', 'una', 'volta', 'il', 'valore', 'della', 'libera', 'informazione', 'Tanti', 'giornalisti', 'rischiano', 'la', 'vita', 'per', 'documentare', 'quel', 'che', 'accade', 'nelle', 'sciagurate', 'guerre', 'ai', 'confini', 'dell', '’', 'Europa', ',', 'in', 'Medio', 'Oriente', 'e', 'altrove', 'Spesso', 'pagano', 'a', 'caro', 'prezzo', 'il', 'servizio', 'che', 'rendono', 'alla', 'comunità', 'La', 'notte', 'di', 'Natale', 'Papa', 'Francesco', '-', 'cui', 'invio', 'auguri', 'pieni', 'di', 'riconoscenza', '-', 'ha', 'aperto', 'il', 'Giubileo', ',', 'facendo', 'risuonare', 'nel', 'mondo', 'il', 'richiamo', 'alla', 'speranza', 'Quelle ...

# %% [markdown]
# ## Scelta del tokenizzatore

# %%
tokenizer = BertTokenizer.from_pretrained("dbmdz/bert-base-italian-uncased", force_download=True)
tokens23 = tokenizer.tokenize(mattarella23) #buuuu
tokens23_nltk = word_tokenize(mattarella23.lower(), language='italian') #per ora meglio

tokens23_nltk_nopunctuation= [word for word in tokens23_nltk if word not in string.punctuation]

tokens23_nltk_nopunctuation_nostopwords= [word for word in tokens23_nltk_nopunctuation if word not in set(stopwords.words('italian'))]

print (tokens23_nltk_nopunctuation_nostopwords)
# Out:
# /home/acarugat/anaconda3/lib/python3.11/site-packages/huggingface_hub/file_download.py:795: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# vocab.txt:   0%|          | 0.00/243k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/59.0 [00:00<?, ?B/s]
# ['care', 'concittadine', 'cari', 'concittadini', 'sera', 'preparando', 'festeggiare', '’', 'arrivo', 'nuovo', 'anno', 'consueta', 'speranza', 'aprano', 'giorni', 'positivi', 'rassicuranti', 'naturalmente', 'possiamo', 'distogliere', 'pensiero', 'avviene', 'intorno', 'italia', 'mondo', 'sappiamo', 'trovarci', 'stagione', 'presenta', 'tanti', 'motivi', 'allarme', 'insieme', 'nuove', 'opportunità', 'avvertiamo', 'angoscia', 'violenza', 'sovente', 'assistiamo', 'stati', 'società', 'strade', 'scene', 'vita', 'quotidiana', 'violenza', 'anzitutto', 'violenza', 'guerre', 'corso', 'evocate', 'minacciate', 'devastazioni', 'vediamo', '’', 'ucraina', 'invasa', 'russia', 'sottometterla', 'annetterla', '’', 'orribile', 'ferocia', 'terroristica', '7', 'ottobre', 'scorso', 'hamas', 'centinaia', 'inermi', 'bambini', 'donne', 'uomini', 'anziani', 'd', '’', 'israele', 'ignobile', 'oltre', 'ogni', 'termine', 'disumanità', 'reazione', 'governo', 'israeliano', '’', 'azione', 'militare', 'provoca', 'migliaia', 'vittime', 'civili', 'costringe', 'gaza', 'moltitudini', 'persone', 'abbandonare', 'proprie', 'case', 'respinti', 'guerra', '–', 'ogni', 'guerra', '–', 'genera', 'odio', '’', 'odio', 'durerà', 'moltiplicato', 'molto', 'tempo', 'dopo', 'fine', 'conflitti', 'guerra', 'frutto', 'rifiuto', 'riconoscersi', 'persone', 'popoli', 'uguali', 'dotati', 'pari', 'dignità', 'affermare', 'invece', 'pretesto', 'proprio', 'interesse', 'nazionale', 'principio', 'diseguaglianza', 'pretende', 'asservire', 'sfruttare', 'cerca', 'giustificare', 'comportamenti', 'sempre', 'avvenuti', 'storia', 'rifiutando', 'progresso', 'civiltà', 'umana', 'rischio', 'concreto', 'abituarsi', 'orrore', 'morti', 'civili', 'donne', 'bambini', 'sempre', 'spesso', '–', 'accade', 'guerre', 'tragica', 'contabilità', 'soldati', 'uccisi', 'reciprocamente', 'presentata', 'menandone', 'vanto', 'vite', 'spezzate', 'famiglie', 'distrutte', 'generazione', 'perduta', 'accade', 'vicino', 'cuore', '’', 'europa', 'rive', 'mediterraneo', 'macerie', 'solo', 'fisiche', 'pesano', 'presente', 'graveranno', 'futuro', 'nuove', 'generazioni', 'fronte', 'quali', 'presentano', 'oggi', 'possibile', 'avvenire', 'brutalità', 'pensavamo', 'ormai', 'scomparse', 'oltre', 'condannate', 'storia', 'guerra', 'nasce', 'sola', 'basterebbe', 'neppure', 'spinta', 'tante', 'armi', 'strumento', 'morte', 'così', 'diffuse', 'sempre', 'letali', 'fonte', 'enormi', 'guadagni', 'nasce', 'quel', '’', '’', 'animo', 'uomini', 'mentalità', 'coltiva', 'atteggiamenti', 'violenza', 'sopraffazione', 'manifestano', 'indispensabile', 'fare', 'spazio', 'cultura', 'pace', 'mentalità', 'pace', 'parlare', 'pace', 'oggi', 'astratto', 'buonismo', 'contrario', 'urgente', 'concreto', 'esercizio', 'realismo', 'vuole', 'cercare', 'via', 'd', '’', 'uscita', 'crisi', 'può', 'essere', 'devastante', 'futuro', '’', 'umanità', 'sappiamo', 'porre', 'fine', 'guerre', 'corso', 'basta', 'invocare', 'pace', 'occorre', 'venga', 'perseguita', 'volontà', 'governi', 'anzitutto', 'scatenato', 'conflitti', 'impegnarsi', 'pace', 'significa', 'considerare', 'guerre', 'eccezione', 'rimuovere', 'regola', 'prossimo', 'futuro', 'volere', 'pace', 'neutralità', 'peggio', 'indifferenza', 'rispetto', 'ciò', 'accade', 'ingiusto', 'piuttosto', 'spregevole', 'perseguire', 'pace', 'vuol', 'dire', 'respingere', 'logica', 'competizione', 'permanente', 'stati', 'mette', 'rischio', 'sorti', 'rispettivi', 'popoli', 'mina', 'basi', 'società', 'fondata', 'rispetto', 'persone', 'conseguire', 'pace', 'sufficiente', 'far', 'tacere', 'armi', 'costruirla', 'significa', 'prima', 'educare', 'pace', 'coltivarne', 'cultura', 'sentimento', 'nuove', 'generazioni', 'gesti', 'vita', 'ogni', 'giorno', 'linguaggio', 'adopera', 'dipende', 'ciascuno', 'pace', 'senso', 'vivere', 'bene', 'insieme', 'rispettandosi', 'riconoscendo', 'ragioni', '’', 'altro', 'consapevoli', 'libertà', 'altri', 'completa', 'libertà', 'vediamo', 'incontriamo', 'violenza', 'vita', 'quotidiana', 'paese', 'quando', 'prevale', 'ricer ...

# %%
tokens24_nltk = word_tokenize(mattarella24, language='italian')
lista_token = []
lista_token.append(tokens24_nltk)
lista_token.append(tokens23_nltk)
lista_mattarella = tokens23_nltk + tokens24_nltk
unique_tokens =list(set(lista_mattarella))
print(unique_tokens)
# Out:
# ['valori', 'studenti', 'scandalo', 'cure', 'attese', 'indispensabile', 'su', 'filtri', 'ho', 'sondaggio', 'oltre', 'fango', 'pone', 'popolazione', 'episodi', 'dedicano', 'Quello', 'cominciare', 'orribile', 'scarsa', 'mondo', 'Perché', 'dollari', 'storie', 'facciamo', 'principe', 'vivendo', 'devastazioni', 'significativi', 'giustificare', 'ampia', 'rispettivi', 'letti', 'economici', 'magistero', 'Una', 'della', 'scarto', 'mutamenti', 'esigenze', 'ignobile', 'Paesi', 'atteggiamento', 'aria', 'fenomeno', 'pieni', 'serenità', 'cercare', 'lavorare', 'registra', 'accettare', 'concretamente', 'civiltà', 'sera', 'vanto', 'urgente', 'sentimento', 'intento', 'millennio', 'prevale', 'volto', 'governo', 'diseguaglianza', 'mortali', 'spinta', 'abitazioni', 'maggior', 'Ricordo', 'reazione', 'oggi', 'aggressioni', 'solitudini', 'costruire', 'ne', 'ogni', 'decide', 'prezzo', 'occhi', 'nelle', 'detenuti', 'illegalità', 'Lo', 'riallacciare', 'rive', 'dotati', 'Quelle', 'pubblico', 'tuttora', 'manifesta', 'incontrati', 'dedicarsi', 'costruzione', 'posto', 'inique', 'siamo', 'enormi', 'inaccettabilmente', 'incide', 'reati', 'generando', 'fosse', 'spalavano', 'giustizia', 'natura', 'valore', 'risorsa', 'sincero', 'lungimiranza', 'quali', 'risuonare', 'appartengono', 'sentite', 'disuguale', 'manca', 'sia', 'studio', 'persone', 'Tanti', 'devono', 'ragioni', 'quindi', 'teatri', 'quotidiana', 'menandone', 'francesco', 'presentata', 'paralimpico', 'nei', 'orgoglio', 'situazioni', 'tensione', 'invasa', 'contribuisce', 'espressione', 'fondamentale', 'termine', 'prevenzione', 'numero', 'attrazione', 'letali', 'web', 'riferimento', 'suicidi', 'tradizione', 'sentono', 'militare', 'nuovi', 'violenza', 'coltivare', 'cui', 'studi', 'feroci', 'tutta', 'sappiamo', 'prepotenza', 'energia', 'umani', 'ispirati', 'volgere', 'essere', 'istituzioni', 'cantavano', 'italiano', 'ricordato', 'arte', 'propone', 'salvare', 'dimensione', 'trasformare', 'venga', 'dello', 'culto', 'dovere', 'aggressività', 'globale', 'incontro', 'una', 'dati', 'innescata', 'medicine', 'soldati', 'Interpreto', 'cifra', 'garantire', 'soccorso', 'va', 'risorse', "l'ho", 'andamento', 'debito', 'Sammy', 'completa', 'presenta', 'affacciano', 'timore', 'terroristica', 'mutamento', 'sfruttare', 'esprimono', 'risultato', 'sproporzione', 'Treccani', 'dopo', 'particolare', 'cornice', 'Ho', 'unirsi', 'assicurano', 'forza', 'ci', 'nostro', 'ama', 'omicidi', 'precarietà', 'contrastare', 'soltanto', 'ricerca', 'nostri', 'rassicuranti', 'difficili', 'sul', 'respirare', 'unità', 'squilibri', 'Italiana', 'ancor', 'ucraina', 'aggressione', 'rispettano', 'peggio', 'primo', 'dolore', 'respinti', 'quanto', 'ingiusto', 'rimozione', 'rito', 'diritto', 'indice', 'impegna', 'provoca', 'Impegniamoci', 'dimostrazione', 'tuttavia', 'tecnologia', 'significa', 'E', 'qualcosa', 'parla', 'riconosce', 'In', 'graveranno', '”', 'Repubblica', 'quelle', 'parte', 'questo', 'differenze', 'davanti', 'dall', 'vita', 'si', 'Che', 'poco', 'talvolta', 'distogliere', 'evitare', 'Censis', 'stiamo', 'sconfortante', 'lunghe', 'cioè', 'percorsi', 'liste', 'alcuni', 'quel', 'mamme', 'storica', 'opportunità', 'anche', 'crimini', 'risentimento', 'export', 'rischiose', 'bell', 'semplici', 'rapporti', 'ottanta', 'sempre', 'accuse', 'rivolgere', 'sostegno', 'costituzione', 'difesa', 'ribellarsi', 'contraddizioni', 'se', 'inguaribili', 'leggi', 'formazione', 'stare', 'strade', 'basta', 'incontrato', 'armamenti', 'cresce', 'saggezza', 'là', 'cerca', 'invece', 'smarrimento', 'festività', 'rassegnazione', 'i', 'fiducia', 'bilancio', 'morte', 'uniti', 'effettiva', 'Il', 'tradursi', 'climatico', 'futuro', 'diffusa', 'impone', 'beni', 'recano', 'poste', 'iintegrazione', 'nasce', 'disorientamento', 'Tocca', 'ambientale', 'obiettivo', 'qualche', 'affrontate', 'città', 'precedenti', 'casal', 'inammissibili', 'lezione', 'accomuna', 'centrali', 'perseguita', 'lacerano', 'successo', 'tradizionale', 'vissuto', 'gravi', 'linguaggio', 'addietro', 'divisa', 'legger ...

# %% [markdown]
# ## Creazione del modello Word2Vec

# %%
model23 = Word2Vec(sentences=[tokens23_nltk, tokens24_nltk], vector_size =100, window=5, min_count = 1, workers = 4, sg=0)

model23.save("mattarella23.model")

# %%
vector = model23.wv["concittadini"]
#print (vector)
similarity = model23.wv.similarity("cari", "concittadini")
print(similarity)
count = model23.wv.get_vecattr("pace","count")
print (count)
# Out:
# -0.011506728
# 19

# %%
modello =
# Out:
#   Cell In[8], line 1
#     modello =
#               ^
# SyntaxError: invalid syntax
